# %%
#Install Required Libraries

# !pip install opencv-python deepface pandas openpyxl



#Python Code: senior_citizen_detection.py
import cv2
from deepface import DeepFace
from datetime import datetime
import pandas as pd
import os

# Output file
csv_path = "population-regions new.csv"

# Create CSV if not exists
if not os.path.exists(csv_path):
    df = pd.DataFrame(columns=["Age", "Gender", "Senior_Citizen", "Timestamp"])
    df.to_csv(csv_path, index=False)

# Load video or webcam
cap = cv2.VideoCapture(0)  # Use 0 for webcam; replace with video file path if needed

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

print("Starting video stream. Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Convert frame to grayscale for face detection
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in faces:
        # Draw rectangle around face
        face_img = frame[y:y+h, x:x+w]
        try:
            # Predict age & gender
            result = DeepFace.analyze(face_img, actions=['age', 'gender'], enforce_detection=False)
            age = result[0]['age']
            gender = result[0]['gender']

            # Check senior status
            is_senior = age > 60

            # Draw bounding box with label
            label = f"{gender}, Age: {age}"
            color = (0, 255, 0) if is_senior else (255, 0, 0)
            cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
            cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

            # Log to CSV
            timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            log_data = pd.DataFrame([[age, gender, is_senior, timestamp]],
                                    columns=["Age", "Gender", "Senior_Citizen", "Timestamp"])
            log_data.to_csv(csv_path, mode='a', header=False, index=False)

        except Exception as e:
            print("Error analyzing face:", e)

    cv2.imshow("Senior Citizen Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# Requirement already satisfied: opencv-python in c:\users\ketaki\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: deepface in c:\users\ketaki\anaconda3\lib\site-packages (0.0.93)
# Requirement already satisfied: pandas in c:\users\ketaki\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: openpyxl in c:\users\ketaki\anaconda3\lib\site-packages (3.1.2)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ketaki\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: requests>=2.27.1 in c:\users\ketaki\anaconda3\lib\site-packages (from deepface) (2.32.2)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\ketaki\anaconda3\lib\site-packages (from deepface) (5.2.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\ketaki\anaconda3\lib\site-packages (from deepface) (4.66.4)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\ketaki\anaconda3\lib\site-packages (from deepface) (10.3.0)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\ketaki\anaconda3\lib\site-packages (from deepface) (2.19.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\ketaki\anaconda3\lib\site-packages (from deepface) (3.9.2)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\ketaki\anaconda3\lib\site-packages (from deepface) (3.0.3)
# Requirement already satisfied: flask-cors>=4.0.1 in c:\users\ketaki\anaconda3\lib\site-packages (from deepface) (6.0.1)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\ketaki\anaconda3\lib\site-packages (from deepface) (1.0.0)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\ketaki\anaconda3\lib\site-packages (from deepface) (0.0.17)
# Requirement already satisfied: fire>=0.4.0 in c:\users\ketaki\anaconda3\lib\site-packages (from deepface) (0.7.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\ketaki\anaconda3\lib\site-packages (from deepface) (23.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ketaki\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ketaki\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ketaki\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: et-xmlfile in c:\users\ketaki\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: termcolor in c:\users\ketaki\anaconda3\lib\site-packages (from fire>=0.4.0->deepface) (3.0.1)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\ketaki\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\ketaki\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\ketaki\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\ketaki\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\ketaki\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (1.6.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\ketaki\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.3)
# Requirement already satisfied: filelock in c:\users\ketaki\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (3.13.1)
# Requirement already satisfied: packaging in c:\users\ketaki\anaconda3\lib\site-packages (from gunicorn>=20.1.0->deepface) (23.2)
# Requirement already satisfied: absl-py in c:\users\ketaki\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (2.2.2)
# Requirement already satisfied: rich in c:\users\ketaki\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (13.3.5)
# Requirement already satisfied: namex in c:\users\ketaki\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (0.0.9)
# Requirement already satisfied: h5py in c:\users\ketaki\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (3.11.0)
# Requirement already satisfied: optree in c:\users\ketaki\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (0.15.0)
# Requirement already satisfied: ml-dtypes in c:\users\ketaki\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (0.5.1)
# Requirement already satisfied: joblib>=1.4.2 in c:\users\ketaki\anaconda3\lib\site-packages (from mtcnn>=0.1.0->deepface) (1.4.2)
# Requirement already satisfied: lz4>=4.3.3 in c:\users\ketaki\anaconda3\lib\site-packages (from mtcnn>=0.1.0->deepface) (4.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\ketaki\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ketaki\anaconda3\lib\site-packages (from requests>=2.27.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ketaki\anaconda3\lib\site-packages (from requests>=2.27.1->deepface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ketaki\anaconda3\lib\site-packages (from requests>=2.27.1->deepface) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ketaki\anaconda3\lib\site-packages (from requests>=2.27.1->deepface) (2024.7.4)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ketaki\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ketaki\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ketaki\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ketaki\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ketaki\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ketaki\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\ketaki\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\ketaki\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (80.9.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ketaki\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ketaki\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ketaki\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\ketaki\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.19.0)
# Requirement already satisfied: colorama in c:\users\ketaki\anaconda3\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ketaki\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.43.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ketaki\anaconda3\lib\site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (2.1.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ketaki\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ketaki\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ketaki\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\ketaki\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\ketaki\anaconda3\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ketaki\anaconda3\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ketaki\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.0)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 9
#       7 #Python Code: senior_citizen_detection.py
#       8 import cv2
# ----> 9 from deepface import DeepFace
#      10 from datetime import datetime
#      11 import pandas as pd
#
# File ~\anaconda3\Lib\site-packages\deepface\DeepFace.py:15
#      13 import numpy as np
#      14 import pandas as pd
# ---> 15 import tensorflow as tf
#      17 # package dependencies
#      18 from deepface.commons import package_utils, folder_utils
#
# File ~\anaconda3\Lib\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:88
#      86     sys.setdlopenflags(_default_dlopen_flags)
#      87 except ImportError:
# ---> 88   raise ImportError(
#      89       f'{traceback.format_exc()}'
#      90       f'\n\nFailed to load the native TensorFlow runtime.\n'
#      91       f'See https://www.tensorflow.org/install/errors '
#      92       f'for some common causes and solutions.\n'
#      93       f'If you need help, create an issue '
#      94       f'at https://github.com/tensorflow/tensorflow/issues '
#      95       f'and include the entire stack trace above this error message.')
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\Ketaki\anaconda3\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 73, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.
